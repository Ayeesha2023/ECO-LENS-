# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayeesha2023/ECO-LENS-/blob/main/V11_model_version1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Connect to Google Drive (if not already connected)
from google.colab import drive
drive.mount('/content/drive')

# 2. Install the latest version of Ultralytics (gets you YOLO11)
# !pip install -U ultralytics

# 3. Import the library
from ultralytics import YOLO

# 4. Initialize the brand new YOLO11 Medium model (It will auto-download the weights)
# Notice we are starting fresh with 'yolo11m.pt', NOT loading our old YOLOv8 weights!
model = YOLO('yolo11m.pt')

# 5. Start Training with Advanced Settings for Small Objects & T4 GPU
results = model.train(
    data='/content/drive/MyDrive/ECO-LENS/Taco/data.yaml', # Check your exact spelling of Taco/TACO
    epochs=55,                                            # Full run
    imgsz=800,                                            # High-res mode for tiny objects (caps, cigarettes)
    device=0,                                             # Use the free T4 GPU
    project='/content/drive/MyDrive/ECO-LENS/runs',       # Save directly to your Drive
    name='ecolens_yolo11m_highres',                       # Name of the new folder
    patience=40,                                          # Safety net: waits 40 epochs before stopping if flatlined
    batch=8,                                              # LOWERED to 8: prevents the T4 GPU from running Out of Memory!
    optimizer='auto'                                      # Let YOLO pick the best learning optimizer natively
)
# Out:
# Mounted at /content/drive
# Collecting ultralytics
#   Downloading ultralytics-8.4.84-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.11.0+cu128)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.26.0+cu128)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.35.2)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (13.610.43)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.20-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (26.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.6.17)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.29.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.8.0->ultralytics) (1.5.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.84-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 30.6 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.20-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.4.84 ultralytics-thop-2.0.20
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 100% ━━━━━━━━━━━━ 38.8MB 241.2MB/s 0.2s
# Ultralytics 8.4.84 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/drive/MyDrive/ECO-LENS/Taco/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dis=6.0, distill_model=None, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=55, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=800, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11m.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=ecolens_yolo11m_highres-2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=40, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/ECO-LENS/runs, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/ECO-LENS/runs/ecolens_yolo11m_highres-2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 21.7MB/s 0.0s
# Overriding model.yaml nc=80 with nc=18
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  23        [16, 19, 22]  1   1424902  ultralytics.nn.modules.head.Detect           [18, 16, None, [256, 512, 512]]
# YOLO11m summary: 232 layers, 20,066,886 parameters, 20,066,870 gradients, 68.3 GFLOPs
#
# Transferred 643/649 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 84.8MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 1.0±0.6 ms, read: 0.1±0.0 MB/s, size: 50.6 KB)
# train: Scanning /content/drive/MyDrive/ECO-LENS/Taco/train/labels... 4200 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4200/4200 2.9it/s 24:06
# train: New cache created: /content/drive/MyDrive/ECO-LENS/Taco/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 6.0±9.6 ms, read: 0.1±0.1 MB/s, size: 41.0 KB)
# val: Scanning /content/drive/MyDrive/ECO-LENS/Taco/valid/labels... 1704 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1704/1704 2.7it/s 10:38
# val: New cache created: /content/drive/MyDrive/ECO-LENS/Taco/valid/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000455, momentum=0.9) with parameter groups 106 weight(decay=0.0), 113 weight(decay=0.0005), 112 bias(decay=0.0)
# Plotting labels to /content/drive/MyDrive/ECO-LENS/runs/ecolens_yolo11m_highres-2/labels.jpg...
# Image sizes 800 train, 800 val
# Using 2 dataloader workers
# Logging results to /content/drive/MyDrive/ECO-LENS/runs/ecolens_yolo11m_highres-2
# Starting training for 55 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/55      6.34G      1.367      3.485       1.34         37        800: 100% ━━━━━━━━━━━━ 525/525 1.9it/s 4:32
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.3it/s 46.5s
#                    all       1704       4830       0.31      0.135     0.0687     0.0435
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/55      6.56G      1.482      2.905       1.41         44        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.7s
#                    all       1704       4830      0.241      0.158     0.0644     0.0396
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/55      6.36G      1.516      2.897      1.439         30        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:17
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.3s
#                    all       1704       4830      0.208      0.165     0.0769     0.0476
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/55      6.35G      1.507      2.821      1.431         46        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.5s
#                    all       1704       4830      0.207      0.158     0.0847     0.0534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/55      6.36G      1.465      2.719      1.407         32        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.7s
#                    all       1704       4830      0.224      0.188      0.112     0.0713
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/55      6.37G      1.413       2.59      1.377         55        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.6s
#                    all       1704       4830        0.3      0.186      0.115      0.077
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/55      6.37G      1.396      2.508      1.365         38        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.7s
#                    all       1704       4830      0.272      0.224      0.142     0.0962
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/55      6.36G      1.365      2.445       1.34         23        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.1s
#                    all       1704       4830      0.255      0.223       0.13      0.089
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/55      6.38G      1.322      2.343      1.318         29        800: 100% ━━━━━━━━━━━━ 525/525 2.1it/s 4:16
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.3s
#                    all       1704       4830      0.276       0.23      0.151      0.101
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/55      6.35G       1.34      2.308      1.318         20        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.3s
#                    all       1704       4830      0.278      0.219      0.143     0.0967
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/55      6.36G      1.299      2.176      1.292         39        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.1s
#                    all       1704       4830      0.308      0.232      0.172      0.117
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/55      6.38G      1.266      2.116      1.274         26        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.8s
#                    all       1704       4830      0.282      0.227      0.178      0.126
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/55      6.35G      1.237      2.069      1.257         64        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.1s
#                    all       1704       4830       0.31      0.245        0.2      0.139
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/55      6.35G      1.232      1.982       1.24         40        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.5s
#                    all       1704       4830      0.305      0.254        0.2      0.137
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/55      6.35G      1.224      1.958      1.253         34        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:17
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.3s
#                    all       1704       4830      0.327      0.252        0.2       0.14
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/55      6.51G      1.205      1.864      1.227         70        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.8s
#                    all       1704       4830      0.341      0.282       0.22      0.153
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/55      6.35G      1.185      1.805      1.219         24        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.4s
#                    all       1704       4830      0.302      0.284      0.228      0.162
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/55      6.36G      1.176      1.747      1.211         58        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.0s
#                    all       1704       4830       0.38      0.273      0.247      0.174
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/55      6.35G      1.149      1.676      1.203         25        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.7s
#                    all       1704       4830      0.365      0.266      0.233      0.165
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/55      6.36G      1.144      1.613      1.196         50        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.2s
#                    all       1704       4830      0.428      0.273      0.258      0.187
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/55      6.35G      1.123      1.569      1.184         36        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.3s
#                    all       1704       4830      0.324      0.312       0.25      0.177
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/55      6.52G      1.113      1.508      1.176         42        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:17
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.6s
#                    all       1704       4830      0.324      0.298      0.249      0.177
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/55      6.34G      1.103      1.465      1.171         24        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 37.9s
#                    all       1704       4830      0.389      0.315       0.28      0.202
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/55      6.37G      1.091      1.424      1.158         23        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.4s
#                    all       1704       4830      0.447      0.313      0.299      0.218
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/55      6.36G      1.082      1.356      1.147         24        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.6s
#                    all       1704       4830      0.396      0.327      0.297      0.214
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/55      6.35G      1.058      1.322      1.141         27        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:17
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 37.9s
#                    all       1704       4830      0.407      0.325      0.302      0.216
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/55      6.35G      1.042      1.255      1.133         29        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:17
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.1s
#                    all       1704       4830      0.451      0.324      0.302      0.219
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/55      6.37G      1.053      1.232      1.137         31        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.8s
#                    all       1704       4830      0.432      0.338       0.32      0.233
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/55      6.35G      1.033      1.197      1.123         30        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.5s
#                    all       1704       4830       0.45      0.337      0.322      0.236
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/55      6.37G      1.006      1.128      1.113         53        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.6s
#                    all       1704       4830      0.454      0.353      0.329      0.238
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/55      6.38G      1.012      1.113      1.109         56        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.0s
#                    all       1704       4830      0.484      0.345      0.333      0.239
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/55      6.35G      1.003      1.079      1.104         36        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.2s
#                    all       1704       4830       0.51      0.346      0.346      0.248
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/55      6.35G     0.9911      1.037      1.099         45        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.7s
#                    all       1704       4830      0.545       0.34      0.351      0.257
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/55      6.35G     0.9566     0.9769      1.085         20        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.1s
#                    all       1704       4830      0.559      0.349      0.365      0.268
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/55      6.37G     0.9653     0.9668       1.08         40        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.3s
#                    all       1704       4830      0.496      0.378      0.368      0.269
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/55      6.34G     0.9581     0.9214      1.076         45        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 37.9s
#                    all       1704       4830      0.511      0.368      0.369      0.272
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/55       6.5G     0.9356     0.8972      1.068         24        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.5s
#                    all       1704       4830      0.559      0.361      0.367      0.272
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/55      6.37G     0.9335     0.8715      1.058         31        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.4s
#                    all       1704       4830      0.535      0.377      0.374      0.277
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/55      6.36G     0.9411     0.8638      1.056         30        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.8s
#                    all       1704       4830      0.561      0.367       0.38      0.281
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/55      6.36G     0.8957     0.8073      1.044         33        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.5s
#                    all       1704       4830      0.589      0.363      0.379      0.276
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/55      6.37G     0.8964     0.7991      1.043         41        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.7s
#                    all       1704       4830      0.581      0.371      0.389      0.285
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/55      6.56G     0.8917     0.7869      1.036         32        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.2s
#                    all       1704       4830      0.568      0.381      0.392      0.294
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/55      6.36G      0.884     0.7559      1.035         37        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.1s
#                    all       1704       4830      0.576      0.377        0.4      0.298
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/55      6.37G     0.8543      0.733      1.019         24        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.0s
#                    all       1704       4830      0.594      0.388      0.408      0.305
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/55      6.37G     0.8635     0.7206      1.019         23        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.1s
#                    all       1704       4830      0.602      0.385      0.405      0.302
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/55      6.35G     0.8106     0.6235     0.9756         17        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.1s
#                    all       1704       4830      0.604      0.392      0.402      0.298
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/55      6.36G     0.8031     0.5847     0.9693         17        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:17
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.5s
#                    all       1704       4830      0.586      0.394      0.409      0.307
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/55      6.36G     0.7905     0.5657     0.9629         31        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 37.9s
#                    all       1704       4830      0.607      0.395      0.405      0.301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/55      6.37G     0.7799     0.5446      0.958         24        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:17
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 37.9s
#                    all       1704       4830      0.604      0.388      0.408      0.306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/55      6.35G     0.7673     0.5306     0.9548         11        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:16
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.0s
#                    all       1704       4830      0.634      0.395      0.421      0.316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/55      6.35G     0.7527     0.5084     0.9432         22        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.0s
#                    all       1704       4830      0.602      0.401      0.413       0.31
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/55      6.36G     0.7456     0.4987      0.942         24        800: 100% ━━━━━━━━━━━━ 525/525 2.1it/s 4:16
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 37.9s
#                    all       1704       4830      0.612      0.401      0.416      0.313
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/55      6.44G     0.7373     0.4935     0.9384         22        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:17
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.7s
#                    all       1704       4830      0.618      0.405      0.416      0.313
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/55      6.33G     0.7274     0.4844     0.9345         22        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:16
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.2s
#                    all       1704       4830       0.63      0.401      0.418      0.317
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/55      6.34G      0.724     0.4823     0.9294         20        800: 100% ━━━━━━━━━━━━ 525/525 2.0it/s 4:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.8it/s 38.1s
#                    all       1704       4830      0.603      0.411      0.417      0.316
#
# 55 epochs completed in 4.603 hours.
# Optimizer stripped from /content/drive/MyDrive/ECO-LENS/runs/ecolens_yolo11m_highres-2/weights/last.pt, 40.6MB
# Optimizer stripped from /content/drive/MyDrive/ECO-LENS/runs/ecolens_yolo11m_highres-2/weights/best.pt, 40.6MB
#
# Validating /content/drive/MyDrive/ECO-LENS/runs/ecolens_yolo11m_highres-2/weights/best.pt...
# Ultralytics 8.4.84 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11m summary (fused): 126 layers, 20,043,910 parameters, 0 gradients, 67.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 107/107 2.6it/s 40.5s
#                    all       1704       4830      0.629      0.401      0.418      0.317
#         Aluminium foil         48         62      0.775      0.484      0.493      0.417
#             Bottle cap        347        459      0.689      0.706      0.681       0.53
#                 Bottle        275        320      0.803      0.484      0.593      0.376
#           Broken glass         13        123      0.459     0.0976     0.0978     0.0408
#                    Can        187        267      0.716       0.73      0.746      0.612
#                 Carton        207        263      0.624      0.517      0.514      0.428
#              Cigarette        223        565      0.618       0.24      0.272      0.129
#                    Cup        162        186      0.601      0.548       0.58       0.48
#                    Lid         82         93      0.732       0.44      0.501      0.398
#           Other litter        148        178      0.583      0.275       0.31      0.254
#          Other plastic        181        265      0.568      0.238      0.257      0.177
#                  Paper        126        178      0.541      0.351      0.332      0.269
#  Plastic bag - wrapper        580        854       0.64      0.598      0.579      0.426
#      Plastic container         83         90      0.586      0.333       0.33       0.28
#                Pop tab         87        125      0.566      0.192      0.202      0.112
#                  Straw        112        120      0.604      0.445       0.43      0.312
#        Styrofoam piece         77        113      0.558      0.292      0.328      0.292
#       Unlabeled litter        291        569      0.656      0.241      0.285      0.167
# Speed: 0.3ms preprocess, 17.0ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to /content/drive/MyDrive/ECO-LENS/runs/ecolens_yolo11m_highres-2
